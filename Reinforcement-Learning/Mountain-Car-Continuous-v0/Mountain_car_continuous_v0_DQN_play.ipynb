# %%
'''
The trained neural network parameters are saved in file below: 

best_solution_for_mountain_car_continuous_v0.data 

You can save the following two files

mountain_car_continuous_v0_DQN_play.py
best_solution_for_mountain_car_continuous_v0.data

in the same directory and run it by:

python mountain_car_continuous_v0_DQN_play.py -m best_solution_for_mountain_car_continuous_v0.data 

or you can run it in jupyter notebook by:

run mountain_car_continuous_v0_DQN_play.py -m best_solution_for_mountain_car_continuous_v0.data 
'''

# %%
'''
The code below is used to presnt the CountainCarContinuous-v0 module from OpenAI Gym visually
'''
import gym
from IPython import display
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib notebook 
env = gym.make('MountainCarContinuous-v0')
env.reset()
img = plt.imshow(env.render(mode='rgb_array'))
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# <img src="data:image/png;base64,..." width="640">
